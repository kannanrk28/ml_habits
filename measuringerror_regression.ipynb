# %%
# Task 1: Create the dataset as a pandas DataFrame
import pandas as pd

data = {
    "CGPA": [6.5, 7.8, 5.2, 8.9, 6.0, 9.1, 7.2, 5.8, 8.5, 7.0],
    "iq": [110, 125, 95, 140, 105, 145, 120, 100, 135, 115],
    "grade": ["B", "A", "C", "A", "B", "A", "B", "C", "A", "B"],
    "placement": ["yes", "yes", "no", "yes", "no", "yes", "yes", "no", "yes", "yes"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    CGPA   iq grade placement
# 0   6.5  110     B       yes
# 1   7.8  125     A       yes
# 2   5.2   95     C        no
# 3   8.9  140     A       yes
# 4   6.0  105     B        no
# 5   9.1  145     A       yes
# 6   7.2  120     B       yes
# 7   5.8  100     C        no
# 8   8.5  135     A       yes
# 9   7.0  115     B       yes

# %%
# Task 2: Apply manual ordinal encoding to the grade column with order C < B < A
df["grade"] = df["grade"].astype(str)
df["grade"] = df["grade"].str.strip().str.upper()
df["grade"] = df["grade"].map({"C": 0, "B": 1, "A": 2})
print(df)
# Out:
#    CGPA   iq  grade placement
# 0   6.5  110      1       yes
# 1   7.8  125      2       yes
# 2   5.2   95      0        no
# 3   8.9  140      2       yes
# 4   6.0  105      1        no
# 5   9.1  145      2       yes
# 6   7.2  120      1       yes
# 7   5.8  100      0        no
# 8   8.5  135      2       yes
# 9   7.0  115      1       yes

# %%
print(df["grade"].dtype)
print(df["grade"].head())
# Out:
# int64
# 0    1
# 1    2
# 2    0
# 3    2
# 4    1
# Name: grade, dtype: int64

# %%
# Task 3: Apply manual label encoding to the placement column (no -> 0, yes -> 1)
placement_mapping = {"no": 0, "yes": 1}
df["placement"] = df["placement"].map(placement_mapping)
print(df["placement"])
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    1
# 6    1
# 7    0
# 8    1
# 9    1
# Name: placement, dtype: int64

# %%
# Task 4: Separate the features into X and the target into y
X = df[['CGPA', 'iq', 'grade']]
y = df["placement"]

# %%
# Task 5: Split the data into training and test sets using a 90-10 split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# %%
# Task 6: Standardize the feature data by fitting on training data and transforming both sets
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Task 7: Train a Logistic Regression model and print the test accuracy
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)

# Task 8: Short comments have been added above each task explaining what it does
# Out:
# Accuracy: 1.0
